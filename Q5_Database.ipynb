# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitalijadhao206-star/Python_Basic_Projects/blob/main/Q5_Database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Database

def student_database():

    d = {}

    while True:

        print("\n1. Add Student")
        print("2. Search Student")
        print("3. Display All")
        print("4. Exit")

        try:
            ch = int(input("Enter Choice: "))

            if ch == 1:
                roll = input("Enter Roll No: ")
                name = input("Enter Name: ")
                age = int(input("Enter Age: "))
                city = input("Enter City: ")

                d.update({roll: [name, age, city]})
                print("Student Added")

            elif ch == 2:
                roll = input("Enter Roll No: ")
                s = d.get(roll)

                if s:
                    print("Name =", s[0])
                    print("Age =", s[1])
                    print("City =", s[2])
                else:
                    print("Student Not Found")

            elif ch == 3:
                for roll, s in d.items():
                    print("\nRoll =", roll)
                    print("Name =", s[0])
                    print("Age =", s[1])
                    print("City =", s[2])

            elif ch == 4:
                print("Thank You")
                break

            else:
                print("Invalid Choice")

        except ValueError:
            print("Enter Correct Input")


student_database()
# Out:
# 1. Add Student
# 2. Search Student
# 3. Display All
# 4. Exit
# Enter Choice: 1
# Enter Roll No: 31
# Enter Name: Chaitali
# Enter Age: 18
# Enter City: Yavatmal
# Student Added
#
# 1. Add Student
# 2. Search Student
# 3. Display All
# 4. Exit
# Enter Choice: 3
#
# Roll = 31
# Name = Chaitali
# Age = 18
# City = Yavatmal
#
# 1. Add Student
# 2. Search Student
# 3. Display All
# 4. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1962/2847121141.py in <cell line: 0>()
#      53
#      54
# ---> 55 student_database()
#
# /tmp/ipykernel_1962/2847121141.py in student_database()
#      13
#      14         try:
# ---> 15             ch = int(input("Enter Choice: "))
#      16
#      17             if ch == 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
