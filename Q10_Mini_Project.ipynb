# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitalijadhao206-star/Python_Basic_Projects/blob/main/Q10_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random

d = {}

while True:

    print("\n1. Basic Arithmetic")
    print("2. Scientific Calculation")
    print("3. Random Number")
    print("4. Store Result")
    print("5. View History")
    print("6. Exit")

    ch = int(input("Enter Choice: "))

    if ch == 1:

        a = int(input("Enter First Number: "))
        b = int(input("Enter Second Number: "))

        print("Addition =", a + b)

        ans = a + b

    elif ch == 2:

        n = int(input("Enter Number: "))

        print("Square Root =", math.sqrt(n))

        ans = math.sqrt(n)

    elif ch == 3:

        ans = random.randint(1, 100)

        print("Random Number =", ans)

    elif ch == 4:

        t = input("Enter Date/Time: ")

        d[t] = ans

        print("Stored Successfully")

    elif ch == 5:

        print("\nHistory")

        for i in d:
            print(i, "=", d[i])

    elif ch == 6:

        print("Thank You")
        break

    else:

        print("Invalid Choice")
# Out:
# 1. Basic Arithmetic
# 2. Scientific Calculation
# 3. Random Number
# 4. Store Result
# 5. View History
# 6. Exit
# Enter Choice: 1
# Enter First Number: 10
# Enter Second Number: 20
# Addition = 30
#
# 1. Basic Arithmetic
# 2. Scientific Calculation
# 3. Random Number
# 4. Store Result
# 5. View History
# 6. Exit
# Enter Choice: 4
# Enter Date/Time: 29-06-2026/9:32
# Stored Successfully
#
# 1. Basic Arithmetic
# 2. Scientific Calculation
# 3. Random Number
# 4. Store Result
# 5. View History
# 6. Exit
# Enter Choice: 5
#
# History
# 29-06-2026/9:32 = 30
#
# 1. Basic Arithmetic
# 2. Scientific Calculation
# 3. Random Number
# 4. Store Result
# 5. View History
# 6. Exit
# Enter Choice: 6
# Thank You
