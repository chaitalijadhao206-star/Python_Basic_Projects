# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitalijadhao206-star/Python_Basic_Projects/blob/main/Q4_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Class

class Student:

    def __init__(self, name, roll):
        self.name = name
        self.roll = roll
        self.marks = []

    def add_mark(self, m):
        if m >= 0 and m <= 100:
            self.marks.append(m)
        else:
            print("Invalid Marks")

    def get_average(self):
        if len(self.marks) == 0:
            return 0
        return sum(self.marks) / len(self.marks)

    def display_info(self):
        print("\nStudent Details")
        print("Name =", self.name)
        print("Roll No =", self.roll)
        print("Marks =", self.marks)
        print("Average =", self.get_average())


name = input("Enter Name: ")
roll = input("Enter Roll No: ")

s = Student(name, roll)

try:
    for i in range(5):
        m = float(input("Enter Mark: "))
        s.add_mark(m)

except ValueError:
    print("Enter numbers only")

s.display_info()
# Out:
# Enter Name: Chaitali
# Enter Roll No: 31
# Enter Mark: 99
# Enter Mark: 98
# Enter Mark: 97
# Enter Mark: 96
# Enter Mark: 95
#
# Student Details
# Name = Chaitali
# Roll No = 31
# Marks = [99.0, 98.0, 97.0, 96.0, 95.0]
# Average = 97.0
